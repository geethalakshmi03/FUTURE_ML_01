# %%
import pandas as pd

data = {
    "Ticket": [
        "Cannot login to my account",
        "Payment failed during checkout",
        "Need help changing password",
        "Website is very slow",
        "Refund not received",
        "App crashes on startup",
        "Unable to update profile",
        "Order delivery delayed"
    ],
    "Category": [
        "Login",
        "Payment",
        "Account",
        "Technical",
        "Payment",
        "Technical",
        "Account",
        "Delivery"
    ]
}

df = pd.DataFrame(data)
df.head()
# Out:
#                            Ticket   Category
# 0      Cannot login to my account      Login
# 1  Payment failed during checkout    Payment
# 2     Need help changing password    Account
# 3            Website is very slow  Technical
# 4             Refund not received    Payment

# %% [markdown]
# from sklearn.feature_extraction.text import CountVectorizer
# from sklearn.model_selection import train_test_split
# from sklearn.naive_bayes import MultinomialNB
# from sklearn.metrics import accuracy_score
#
# X = df["Ticket"]
# y = df["Category"]
#
# vectorizer = CountVectorizer()
# X_vectorized = vectorizer.fit_transform(X)
#
# X_train, X_test, y_train, y_test = train_test_split(
#     X_vectorized, y, test_size=0.25, random_state=42
# )
#
# model = MultinomialNB()
# model.fit(X_train, y_train)
#
# y_pred = model.predict(X_test)
#
# print("Accuracy:", accuracy_score(y_test, y_pred))

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score

X = df["Ticket"]
y = df["Category"]

vectorizer = CountVectorizer()
X_vectorized = vectorizer.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(
    X_vectorized, y, test_size=0.25, random_state=42
)

model = MultinomialNB()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.0

# %%
priority = {
    "Login": "Medium",
    "Payment": "High",
    "Account": "Low",
    "Technical": "High",
    "Delivery": "Medium"
}

df["Priority"] = df["Category"].map(priority)

print(df)
# Out:
#                            Ticket   Category Priority
# 0      Cannot login to my account      Login   Medium
# 1  Payment failed during checkout    Payment     High
# 2     Need help changing password    Account      Low
# 3            Website is very slow  Technical     High
# 4             Refund not received    Payment     High
# 5          App crashes on startup  Technical     High
# 6        Unable to update profile    Account      Low
# 7          Order delivery delayed   Delivery   Medium

# %%
print("Model Accuracy:", accuracy_score(y_test, y_pred))
print("\nTask 2 Completed Successfully!")
# Out:
# Model Accuracy: 0.0
#
# Task 2 Completed Successfully!
